# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# ## Customer Clustering with KMeans to Boost Business Strategy

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# <p style='color: red'>The purpose of this lab is to show you how to use the KMeans algorithm to cluster customer data.</p>

# %% [markdown]
# ## __Table of Contents__
# <ol>
#   <li>
#     <a href="#Objectives">Objectives
#     </a>
#   </li>
#   <li>
#     <a href="#Datasets">Datasets
#     </a>
#   </li>
#   <li>
#     <a href="#Setup">Setup
#     </a>
#     <ol>
#       <li>
#         <a href="#Installing-Required-Libraries">Installing Required Libraries
#         </a>
#       </li>
#       <li>
#         <a href="#Importing-Required-Libraries">Importing Required Libraries
#         </a>
#       </li>
#     </ol>
#   </li>
#   <li>
#     <a href="#Examples">Examples
#     </a>
#     <ol>
#       <li>
#         <a href="#Task-1---Load-the-data-in-a-csv-file-into-a-dataframe">Task 1 - Load the data in a csv file into a dataframe
#         </a>
#       </li>
#       <li>
#         <a href="#Task-2---Decide-how-many-clusters-to-create">Task 2 - Decide how many clusters to create
#         </a>
#       </li>
#       <li>
#         <a href="#Task-3---Create-a-clustering-model">Task 3 - Create a clustering model
#         </a>
#       </li>
#       <li>
#         <a href="#Task-4---Make-Predictions">Task 4 - Make Predictions
#         </a>
#       </li>
#     </ol>
#   </li>
#
#   <li>
#     <a href="#Exercises">Exercises
#     </a>
#   </li>
#   <ol>
#     <li>
#       <a href="#Exercise-1---Load-the-data-in-a-csv-file-into-a-dataframe">Exercise 1 - Load the data in a csv file into a dataframe
#       </a>
#     </li>
#     <li>
#       <a href="#Exercise-2---Decide-how-many-clusters-to-create">Exercise 2 - Decide how many clusters to create
#       </a>
#     </li>
#     <li>
#       <a href="#Exercise-3---Create-a-clustering-model">Exercise 3 - Create a clustering model
#       </a>
#     </li>
#     <li>
#       <a href="#Exercise-4---Make-Predictions">Exercise 4 - Make Predictions
#       </a>
#     </li>
#   </ol>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Use Pandas to load data sets.
#  - Use K Means algorithm to cluter the data.

# %% [markdown]
# ## Datasets
#
# In this lab you will be using dataset(s):
#
#  - Modified version of Wholesale customers dataset. Original dataset available at https://archive.ics.uci.edu/ml/datasets/Wholesale+customers
#  - Seeds dataset. Available at https://archive.ics.uci.edu/ml/datasets/seeds

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !pip install pandas==1.3.4
# !pip install scikit-learn==0.20.1

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
#None

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %% [markdown]
# ## Clustering demo with generated sample data

# %%
# Generate sample data for clustering
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=0)
X.shape
# X now contains 300 rows of data spread across 4 clusters that was generated by the make_blobs function.
# In real life we would use an existing data set.
# Out:
# (300, 2)

# %%
# Apply k-means clustering
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
# Print cluster centers
kmeans.cluster_centers_
# Out:
# array([[-1.37324398,  7.75368871],
#        [ 1.98258281,  0.86771314],
#        [ 0.94973532,  4.41906906],
#        [-1.58438467,  2.83081263]])

# %%
# Plot the clusters and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=400, color='black')
plt.show()

# %% [markdown]
# End of Demo

# %% [markdown]
# # Examples

# %% [markdown]
# ## Task 1 - Load the data in a csv file into a dataframe

# %%
# the data set is available at the url below.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/customers.csv"

# using the read_csv function in the pandas library, we load the data into a dataframe.

df = pd.read_csv(URL)

# %% [markdown]
# Let's look at some sample rows from the dataset we loaded:

# %%
# show 5 random rows from the dataset
df.sample(5)
# Out:
#      Fresh_Food   Milk  Grocery  Frozen_Food
# 86        22925  73498    32114          987
# 239       47493   2567     3779         5243
# 139        5387   4979     3343          825
# 336       13970   1511     1330          650
# 276       27901   3749     6964         4479

# %% [markdown]
# Let's find out the number of rows and columns in the dataset:

# %%
df.shape
# Out:
# (440, 4)

# %% [markdown]
# Let's plot the histograms of all columns

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Fresh_Food'}>,
#         <Axes: title={'center': 'Milk'}>],
#        [<Axes: title={'center': 'Grocery'}>,
#         <Axes: title={'center': 'Frozen_Food'}>]], dtype=object)

# %% [markdown]
# ## Task 2 - Decide how many clusters to create

# %% [markdown]
# You must tell the KMeans algorithm how many clusters to create out of your data

# %%
number_of_clusters = 3

# %% [markdown]
# ## Task 3 - Create a clustering model

# %% [markdown]
# Create a KMeans clustering model

# %%
cluster = KMeans(n_clusters = number_of_clusters)

# %% [markdown]
# Train the model on the dataset

# %%
result = cluster.fit_transform(df)

# %% [markdown]
# Your model is now trained. Print cluster centers

# %%
cluster.cluster_centers_
# Out:
# array([[ 8234.99093656,  3824.33836858,  5322.42296073,  2568.73716012],
#        [35941.4       ,  6044.45      ,  6288.61666667,  6713.96666667],
#        [ 8119.69387755, 18812.93877551, 27745.36734694,  2011.42857143]])

# %% [markdown]
# ## Task 4 - Make Predictions

# %% [markdown]
# Make the predictions and save them into the column "cluster_number"

# %%
df['cluster_number'] = cluster.predict(df)

# %%
df.sample(5)
# Out:
#      Fresh_Food   Milk  Grocery  Frozen_Food  cluster_number
# 341        2320   5763    11238          767               0
# 220       14755    899     1382         1765               0
# 155        1989  10690    19460          233               2
# 281       12238   7108     6235         1093               0
# 193         180   3485    20292          959               0

# %% [markdown]
# Print the cluster numbers and the number of customers in each cluster

# %%
df.cluster_number.value_counts()
# Out:
# cluster_number
# 0    331
# 1     60
# 2     49
# Name: count, dtype: int64

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise 1 - Load the data in a csv file into a dataframe

# %%
URL2 = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/seeds.csv"

# %% [markdown]
# Load the seeds dataset available at URL2

# %%
df2 = pd.read_csv(URL2)
df2.head()
# Out:
#     area  perimeter  compactness  length of kernel  width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    asymmetry coefficient  length of kernel groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the read_csv function
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df2 = pd.read_csv(URL2)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 - Decide how many clusters to create

# %% [markdown]
# Cluster the data into 4 clusters

# %%
number_of_clusters = 4

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# set the variable number_of_clusters
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# number_of_clusters = 4
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 - Create a clustering model

# %% [markdown]
# Create a clustering model and train it using the data in the dataframe

# %%
cluster = KMeans(n_clusters = number_of_clusters)
result = cluster.fit_transform(df2)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# use the fit_transform of KMeans
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# cluster = KMeans(n_clusters = number_of_clusters)
# result = cluster.fit_transform(df2)
# ```
#
# </details>

# %%
print(cluster.cluster_centers_)
# Out:
# [[13.38744681 13.86468085  0.87411277  5.36661702  3.11334043  2.45285319
#    4.99274468]
#  [18.96296296 16.39666667  0.88595185  6.24272222  3.74992593  3.54033333
#    6.10077778]
#  [11.89430769 13.25261538  0.84996923  5.22870769  2.86076923  5.08230769
#    5.10561538]
#  [15.71909091 14.97659091  0.88038636  5.74518182  3.3985      3.18704773
#    5.44838636]]

# %%
# Here I try to use the fit method instead of the fit_transform method
# ChatGPT tells it is better to use fit rather than fit_transform to train a KMeans model
# Recall that the first step is to randomly choose the centroids: the result can be different every time the model is trained
# To avoid this, fix the random_state parameter
cluster_bis = KMeans(n_clusters = number_of_clusters, random_state=40)
result_bis = cluster_bis.fit(df2)
print(cluster_bis.cluster_centers_)
# Out:
# [[11.89430769 13.25261538  0.84996923  5.22870769  2.86076923  5.08230769
#    5.10561538]
#  [18.96296296 16.39666667  0.88595185  6.24272222  3.74992593  3.54033333
#    6.10077778]
#  [13.38744681 13.86468085  0.87411277  5.36661702  3.11334043  2.45285319
#    4.99274468]
#  [15.71909091 14.97659091  0.88038636  5.74518182  3.3985      3.18704773
#    5.44838636]]

# %%
# How to evaluate a k-means algorithm? One way is to minimize some metrics such as the Inertia or the Dunn Index
# Minimization is performed by using the elbow method with respect to the number k of clusters.
# Here we show how

# fitting multiple k-means algorithms and storing the values in an empty list
SSE = []
for cluster in range(1,20):
    kkmeans = KMeans(n_clusters = cluster, init='k-means++')
    kkmeans.fit(df2)
    SSE.append(kkmeans.inertia_)

# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
kmeans.cluster_centers_
# The output is a numpy array with the centers' coordinates as lists.
# Out:
# array([[-1.37324398,  7.75368871],
#        [ 1.98258281,  0.86771314],
#        [ 0.94973532,  4.41906906],
#        [-1.58438467,  2.83081263]])

# %%
kmeans.cluster_centers_[:, 0]
# Select the first entry from each list in the array
# Out:
# array([-1.37324398,  1.98258281,  0.94973532, -1.58438467])

# %%
df2.head()
# Out:
#     area  perimeter  compactness  length of kernel  width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    asymmetry coefficient  length of kernel groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %%
# Looking at the above elbow curve, we can choose any number of clusters between 5 to 8.
# We set the number of clusters as 6 and fit the model
kmeans2 = KMeans(n_clusters = 6, init='k-means++', random_state=40)
kmeans2.fit(df2)
X2=df2.to_numpy()
X2 #this is a numpy array
# Out:
# array([[15.26  , 14.84  ,  0.871 , ...,  3.312 ,  2.221 ,  5.22  ],
#        [14.88  , 14.57  ,  0.8811, ...,  3.333 ,  1.018 ,  4.956 ],
#        [14.29  , 14.09  ,  0.905 , ...,  3.337 ,  2.699 ,  4.825 ],
#        ...,
#        [13.2   , 13.66  ,  0.8883, ...,  3.232 ,  8.315 ,  5.056 ],
#        [11.84  , 13.21  ,  0.8521, ...,  2.836 ,  3.598 ,  5.044 ],
#        [12.3   , 13.34  ,  0.8684, ...,  2.974 ,  5.637 ,  5.063 ]])

# %%
# Some plotting
plt.scatter(X2[:, 0], X2[:, 1], c=kmeans2.labels_, cmap='viridis')
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], marker='*', s=400, color='black')
plt.xlabel("area")
plt.ylabel("perimeter")
plt.show()

# %%
# Some plotting
plt.scatter(X2[:, 0], X2[:, 2], c=kmeans2.labels_, cmap='viridis')
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 2], marker='*', s=400, color='black')
plt.xlabel("area")
plt.ylabel("compactness")
plt.show()

# %%
# Some plotting
plt.scatter(X2[:, 0], X2[:, 3], c=kmeans2.labels_, cmap='viridis')
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 3], marker='*', s=400, color='black')
plt.xlabel("area")
plt.ylabel("length of kernel")
plt.show()

# %% [markdown]
# ### Exercise 4 - Make Predictions

# %% [markdown]
# Make the predictions and save them into the column "cluster_number"

# %%
#your code goes here
df2["cluster_number"] = cluster.predict(df2)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# use cluster.predict
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df2['cluster_number'] = cluster.predict(df2)
#
# ```
#
# </details>

# %%
df2.sample(5)
# Out:
#       area  perimeter  compactness  length of kernel  width of kernel  \
# 58   15.38      14.77       0.8857             5.662            3.419
# 110  18.45      16.12       0.8921             6.107            3.769
# 161  12.02      13.33       0.8503             5.350            2.810
# 65   12.88      13.50       0.8879             5.139            3.119
# 3    13.84      13.94       0.8955             5.324            3.379
#
#      asymmetry coefficient  length of kernel groove  cluster_number
# 58                   1.999                    5.222               3
# 110                  2.235                    5.794               1
# 161                  4.271                    5.308               2
# 65                   2.352                    4.607               0
# 3                    2.259                    4.805               0

# %% [markdown]
# Print the cluster numbers and the number of seeds in each cluster

# %%
#your code goes here
df2.cluster_number.value_counts()
# Out:
# cluster_number
# 2    65
# 1    54
# 0    47
# 3    44
# Name: count, dtype: int64

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# use the value_counts() method on cluster_number column
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df2.cluster_number.value_counts()
#
# ```
#
# </details>

# %%
# By default, the value_count method order by frequencies. However, the value_counts() 
# function returns an object containing counts of unique values, hence it cannot be ordered
# by cluster_numbers! Sorting must be performed before counting.
df2.cluster_number.sort_values().value_counts(sort=False)
# Out:
# cluster_number
# 0    47
# 1    54
# 2    65
# 3    44
# Name: count, dtype: int64

# %% [markdown]
# Congratulations you have completed this lab.<br>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Ramesh Sannareddy](https://www.linkedin.com/in/rsannareddy/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01)

# %% [markdown]
# ## Contributors
# [Vicky Kuo](https://author.skills.network/instructors/vicky_kuo?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01)

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-04-14|0.1|Ramesh Sannareddy|Initial Version Created|
# |2023-06-20|0.3|Vicky Kuo|Proofreading|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
